# %% [markdown]
# # ANN- SLEEP HEALTH DATASET(REGRESSION)

# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("C:/Users/mohan/Downloads/Sleep_Health_and_Lifestyle_Dataset.csv")
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])
df['Occupation']=le.fit_transform(df['Occupation'])
df['BMI Category']=le.fit_transform(df['BMI Category'])
df['Sleep Disorder']=le.fit_transform(df['Sleep Disorder'])

# %%
df=df.drop(columns='Person ID',axis=1)
df=df.drop(columns='Occupation',axis=1)
df=df.drop(columns='Blood Pressure',axis=1)
df=df.drop(columns='Heart Rate',axis=1)
df=df.drop(columns='Daily Steps',axis=1)
df=df.drop(columns='Sleep Disorder',axis=1)

# %%
df
# Out:
#      Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0         1   27             6.1                 6                       42
# 1         1   28             6.2                 6                       60
# 2         1   28             6.2                 6                       60
# 3         1   28             5.9                 4                       30
# 4         1   28             5.9                 4                       30
# ..      ...  ...             ...               ...                      ...
# 369       0   59             8.1                 9                       75
# 370       0   59             8.0                 9                       75
# 371       0   59             8.1                 9                       75
# 372       0   59             8.1                 9                       75
# 373       0   59             8.1                 9                       75
#
#      Stress Level  BMI Category
# ...

# %%
y=df["Quality of Sleep"]
y
# Out:
# 0      6
# 1      6
# 2      6
# 3      4
# 4      4
#       ..
# 369    9
# 370    9
# 371    9
# 372    9
# 373    9
# Name: Quality of Sleep, Length: 374, dtype: int64

# %%
x=df.drop(columns='Quality of Sleep',axis=1)
x
# Out:
#      Gender  Age  Sleep Duration  Physical Activity Level  Stress Level  \
# 0         1   27             6.1                       42             6
# 1         1   28             6.2                       60             8
# 2         1   28             6.2                       60             8
# 3         1   28             5.9                       30             8
# 4         1   28             5.9                       30             8
# ..      ...  ...             ...                      ...           ...
# 369       0   59             8.1                       75             3
# 370       0   59             8.0                       75             3
# 371       0   59             8.1                       75             3
# 372       0   59             8.1                       75             3
# 373       0   59             8.1                       75             3
#
#      BMI Category
# 0               3
# 1               0
# 2               0
# 3               2
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scale = scaler.fit_transform(x_train)
x_test_scale = scaler.transform(x_test)

# %%
from tensorflow import keras

# Check number of input features
print(x_train.shape)
print(y_train.shape)

model = keras.Sequential([
    keras.layers.Input(shape=(x_train.shape[1],)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1)  # Single output for regression
])

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

history = model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# (299, 6)
# (299,)
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - loss: 10.0496 - mae: 2.5407 - val_loss: 2.0876 - val_mae: 1.2039
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.8279 - mae: 1.3284 - val_loss: 2.4728 - val_mae: 1.3407
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.0919 - mae: 1.2357 - val_loss: 1.4145 - val_mae: 1.0462
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.4442 - mae: 0.9858 - val_loss: 0.9759 - val_mae: 0.8006
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2909 - mae: 0.9080 - val_loss: 0.8783 - val_mae: 0.8013
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0632 - mae: 0.8183 - val_loss: 1.0062 - val_mae: 0.7832
# Epoch 7/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8932 - mae: 0.7772 - val_loss: 0.5913 - val_mae: 0.6441
# Epoch 8/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.8207 - mae: 0.7310 - val_loss: 0.6228 - val_mae: 0.6485
# Epoch 9/20
# ...

# %%
train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)

print("Training Accuracy :", round(train_accuracy * 100, 2), "%")
print("Testing Accuracy  :", round(test_accuracy * 100, 2), "%")
# Out:
# Training Accuracy : 34.64 %
# Testing Accuracy  : 29.83 %
