# %% [markdown]
# # CLASSIFICATION_PR-HEART ATTACK PREDICTION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import  RandomForestClassifier

# %%
df = pd.read_csv("C:/Users/mohan/Downloads/heart_attack_prediction_india (2).csv")
df
# Out:
#       Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0      69       0                4                     109          487
# 1      32       0                2                     125          170
# 2      89       0                2                     186          543
# 3      78       0                2                     104          367
# 4      38       1                1                     151          158
# ...   ...     ...              ...                     ...          ...
# 6995   69       1                4                     144          110
# 6996   23       0                1                     177          481
# 6997   86       1                2                     174          315
# 6998   91       0                4                     198          129
# 6999   26       0                3                     132          193
#
#       Resting ECG Results  Smoking History  Diabetes History  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     7000 non-null   int64
#  1   Gender                  7000 non-null   int64
#  2   Chest Pain Type         7000 non-null   int64
#  3   Resting Blood Pressure  7000 non-null   int64
#  4   Cholesterol             7000 non-null   int64
#  5   Resting ECG Results     7000 non-null   int64
#  6   Smoking History         7000 non-null   int64
#  7   Diabetes History        7000 non-null   int64
#  8   Alcohol Consumption     7000 non-null   int64
#  9   Heart Attack Risk       7000 non-null   int64
# dtypes: int64(10)
# memory usage: 547.0 KB

# %%
df.describe()
# Out:
#                Age       Gender  Chest Pain Type  Resting Blood Pressure  \
# count  7000.000000  7000.000000      7000.000000             7000.000000
# mean     58.227857     0.492571         2.507857              144.207857
# std      23.511403     0.499981         1.119491               31.682105
# min      18.000000     0.000000         1.000000               90.000000
# 25%      38.000000     0.000000         2.000000              117.000000
# 50%      58.000000     0.000000         3.000000              144.000000
# 75%      78.000000     1.000000         4.000000              172.000000
# max      99.000000     1.000000         4.000000              199.000000
#
#        Cholesterol  Resting ECG Results  Smoking History  Diabetes History  \
# count  7000.000000          7000.000000      7000.000000       7000.000000
# mean    351.351000             0.489571         0.497714          0.493571
# std     146.303141             0.499927         0.500030          0.499994
# ...

# %%
df2=df.copy()
df2
# Out:
#       Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0      69       0                4                     109          487
# 1      32       0                2                     125          170
# 2      89       0                2                     186          543
# 3      78       0                2                     104          367
# 4      38       1                1                     151          158
# ...   ...     ...              ...                     ...          ...
# 6995   69       1                4                     144          110
# 6996   23       0                1                     177          481
# 6997   86       1                2                     174          315
# 6998   91       0                4                     198          129
# 6999   26       0                3                     132          193
#
#       Resting ECG Results  Smoking History  Diabetes History  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                       0
# Gender                    0
# Chest Pain Type           0
# Resting Blood Pressure    0
# Cholesterol               0
# Resting ECG Results       0
# Smoking History           0
# Diabetes History          0
# Alcohol Consumption       0
# Heart Attack Risk         0
# dtype: int64

# %%
df.shape
# Out:
# (7000, 10)

# %%
df.corr()
# Out:
#                              Age    Gender  Chest Pain Type  \
# Age                     1.000000  0.006276        -0.000418
# Gender                  0.006276  1.000000         0.011208
# Chest Pain Type        -0.000418  0.011208         1.000000
# Resting Blood Pressure  0.014267  0.001356         0.007630
# Cholesterol            -0.011023 -0.001790         0.016219
# Resting ECG Results    -0.015448  0.009122         0.006273
# Smoking History        -0.024171  0.004504         0.009348
# Diabetes History        0.004056 -0.003335         0.011577
# Alcohol Consumption     0.008874 -0.016047         0.000665
# Heart Attack Risk       0.009113  0.030588         0.004078
#
#                         Resting Blood Pressure  Cholesterol  \
# Age                                   0.014267    -0.011023
# Gender                                0.001356    -0.001790
# Chest Pain Type                       0.007630     0.016219
# Resting Blood Pressure                1.000000    -0.025048
# ...

# %%
df
# Out:
#       Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0      69       0                4                     109          487
# 1      32       0                2                     125          170
# 2      89       0                2                     186          543
# 3      78       0                2                     104          367
# 4      38       1                1                     151          158
# ...   ...     ...              ...                     ...          ...
# 6995   69       1                4                     144          110
# 6996   23       0                1                     177          481
# 6997   86       1                2                     174          315
# 6998   91       0                4                     198          129
# 6999   26       0                3                     132          193
#
#       Resting ECG Results  Smoking History  Diabetes History  \
# ...

# %%
y=df["Heart Attack Risk"]
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 6995    0
# 6996    1
# 6997    1
# 6998    0
# 6999    1
# Name: Heart Attack Risk, Length: 7000, dtype: int64

# %%
x=df.drop(columns="Heart Attack Risk",axis=1)
x
# Out:
#       Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0      69       0                4                     109          487
# 1      32       0                2                     125          170
# 2      89       0                2                     186          543
# 3      78       0                2                     104          367
# 4      38       1                1                     151          158
# ...   ...     ...              ...                     ...          ...
# 6995   69       1                4                     144          110
# 6996   23       0                1                     177          481
# 6997   86       1                2                     174          315
# 6998   91       0                4                     198          129
# 6999   26       0                3                     132          193
#
#       Resting ECG Results  Smoking History  Diabetes History  \
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
obj_1=StandardScaler()
x_train_scaled=obj_1.fit_transform(x_train)
x_test_scaled=obj_1.transform(x_test)

# %%
df['Heart Attack Risk'].value_counts()
# Out:
# Heart Attack Risk
# 1    3503
# 0    3497
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority')
X_sm, y_sm = smote.fit_resample(x_train, y_train)

y_sm.value_counts()
# Out:
# Heart Attack Risk
# 0    2820
# 1    2820
# Name: count, dtype: int64

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
model1=LogisticRegression()
model1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#testing accuracy
y_pred=model1.predict(x_test)
fs=accuracy_score(y_pred,y_test)
fs
# Out:
# 0.5121428571428571

# %%
#training accuracy
y_train_pred=model1.predict(x_train)
final_training=accuracy_score(y_train_pred,y_train)
final_training
# Out:
# 0.51875

# %%
from sklearn.metrics import confusion_matrix, classification_report

cr = classification_report(y_test, y_pred, target_names=["0", "1"])

print("\nClassification Report:")
print(cr)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.47      0.50       717
#            1       0.50      0.56      0.53       683
#
#     accuracy                           0.51      1400
#    macro avg       0.51      0.51      0.51      1400
# weighted avg       0.51      0.51      0.51      1400

# %% [markdown]
# # KNN

# %%
model2=KNeighborsClassifier()
model2.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#testing accuracy
y_pred=model2.predict(x_test)
fs=accuracy_score(y_pred,y_test)
fs
# Out:
# 0.4857142857142857

# %%
#training accuracy
y_train_pred=model2.predict(x_train)
final_training=accuracy_score(y_train_pred,y_train)
final_training
# Out:
# 0.6766071428571429

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint


param_dist ={'n_neighbors': [3,5,7], 'metric': ['euclidean', 'manhattan'] }

rf =KNeighborsClassifier()

rand_search = RandomizedSearchCV(rf, param_distributions = param_dist,n_iter=5, cv=5,verbose=1, n_jobs=-1)

rand_search.fit(x_train, y_train)
print("Best Hyperparameters:")
print(rand_search.best_params_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Best Hyperparameters:
# {'n_neighbors': 3, 'metric': 'manhattan'}

# %%
model23=KNeighborsClassifier(n_neighbors=3, metric='manhattan')
model23.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=3)

# %%
#testing accuracy
y_pred=model23.predict(x_test)
fs=accuracy_score(y_pred,y_test)
fs
# Out:
# 0.5135714285714286

# %%
#training accuracy
y_train_pred=model2.predict(x_train)
final_training=accuracy_score(y_train_pred,y_train)
final_training
# Out:
# 0.6766071428571429

# %%
from sklearn.metrics import confusion_matrix, classification_report

cr = classification_report(y_test, y_pred, target_names=["0", "1"])

print("\nClassification Report:")
print(cr)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.51      0.52       717
#            1       0.50      0.51      0.51       683
#
#     accuracy                           0.51      1400
#    macro avg       0.51      0.51      0.51      1400
# weighted avg       0.51      0.51      0.51      1400

# %% [markdown]
# # SVM

# %%
model3=SVC()
model3.fit(x_train,y_train)
# Out:
# SVC()

# %%
#testing accuracy
y_pred=model3.predict(x_test)
fs=accuracy_score(y_pred,y_test)
fs
# Out:
# 0.48857142857142855

# %%
#training accuracy
y_train_pred=model3.predict(x_train)
final_training=accuracy_score(y_train_pred,y_train)
final_training
# Out:
# 0.5160714285714286

# %%
from sklearn.model_selection import GridSearchCV 
model_1 = SVC()
parameter = {'C': [0.1, 1, 7,0.4], 'kernel': ['linear', 'rbf'] }
grid = GridSearchCV( estimator=model_1, param_grid=parameter, cv=5, scoring='accuracy' )
grid.fit(x_train, y_train)
print("Best parameters:", grid.best_params_)
print("Best CV score:", grid.best_score_)
# Out:
# Best parameters: {'C': 0.1, 'kernel': 'linear'}
# Best CV score: 0.5232142857142856

# %%
model34=SVC(C=0.1, kernel='linear')
model34.fit(x_train,y_train)
# Out:
# SVC(C=0.1, kernel='linear')

# %%
#testing accuracy
y_pred=model34.predict(x_test)
fs=accuracy_score(y_pred,y_test)
fs
# Out:
# 0.5214285714285715

# %%
#training accuracy
y_train_pred=model34.predict(x_train)
final_training=accuracy_score(y_train_pred,y_train)
final_training
# Out:
# 0.5232142857142857

# %%
from sklearn.metrics import confusion_matrix, classification_report

cr = classification_report(y_test, y_pred, target_names=["0", "1"])

print("\nClassification Report:")
print(cr)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.52      0.53       717
#            1       0.51      0.52      0.52       683
#
#     accuracy                           0.52      1400
#    macro avg       0.52      0.52      0.52      1400
# weighted avg       0.52      0.52      0.52      1400

# %% [markdown]
# # NAIVE BAYES

# %%
model4=GaussianNB()
model4.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
#testing accuracy
y_pred=model4.predict(x_test)
fs=accuracy_score(y_pred,y_test)
fs
# Out:
# 0.5071428571428571

# %%
#training accuracy
y_train_pred=model4.predict(x_train)
final_training=accuracy_score(y_train_pred,y_train)
final_training
# Out:
# 0.5273214285714286

# %%
from sklearn.metrics import confusion_matrix, classification_report

cr = classification_report(y_test, y_pred, target_names=["0", "1"])

print("\nClassification Report:")
print(cr)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.52      0.47      0.49       717
#            1       0.50      0.55      0.52       683
#
#     accuracy                           0.51      1400
#    macro avg       0.51      0.51      0.51      1400
# weighted avg       0.51      0.51      0.51      1400

# %% [markdown]
# # DECISION TREE

# %%
df2
# Out:
#       Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0      69       0                4                     109          487
# 1      32       0                2                     125          170
# 2      89       0                2                     186          543
# 3      78       0                2                     104          367
# 4      38       1                1                     151          158
# ...   ...     ...              ...                     ...          ...
# 6995   69       1                4                     144          110
# 6996   23       0                1                     177          481
# 6997   86       1                2                     174          315
# 6998   91       0                4                     198          129
# 6999   26       0                3                     132          193
#
#       Resting ECG Results  Smoking History  Diabetes History  \
# ...

# %%
y=df2["Heart Attack Risk"]
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 6995    0
# 6996    1
# 6997    1
# 6998    0
# 6999    1
# Name: Heart Attack Risk, Length: 7000, dtype: int64

# %%
x=df2.drop(columns="Heart Attack Risk",axis=1)
x
# Out:
#       Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0      69       0                4                     109          487
# 1      32       0                2                     125          170
# 2      89       0                2                     186          543
# 3      78       0                2                     104          367
# 4      38       1                1                     151          158
# ...   ...     ...              ...                     ...          ...
# 6995   69       1                4                     144          110
# 6996   23       0                1                     177          481
# 6997   86       1                2                     174          315
# 6998   91       0                4                     198          129
# 6999   26       0                3                     132          193
#
#       Resting ECG Results  Smoking History  Diabetes History  \
# ...

# %%
x2_train,x2_test,y2_train,y2_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model5= DecisionTreeClassifier()
model5.fit(x2_train,y2_train)
# Out:
# DecisionTreeClassifier()

# %%
#testing accuracy
y2_pred=model5.predict(x2_test)
fs=accuracy_score(y2_pred,y2_test)
fs
# Out:
# 0.5035714285714286

# %%
#training accuracy
y2_train_pred=model5.predict(x2_train)
final_training=accuracy_score(y2_train_pred,y2_train)
final_training
# Out:
# 1.0

# %%
param_grid = {
    'max_depth': [3, 5, 10],
    'min_samples_split': [2,5,6,7,3,10],
    'min_samples_leaf': [1, 2,3,4]
}
grid_search = GridSearchCV(
    estimator=model5,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
grid_search.fit(x2_train, y2_train)
print("Best Parameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y2_pred = best_model.predict(x2_test)
print("Accuracy:", accuracy_score(y2_test,y2_pred))
# Out:
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 7}
# Accuracy: 0.5135714285714286

# %%
model56= DecisionTreeClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=7)
model56.fit(x2_train,y2_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=7)

# %%
#testing accuracy
y2_pred=model56.predict(x2_test)
fs=accuracy_score(y2_pred,y2_test)
fs
# Out:
# 0.5135714285714286

# %%
#training accuracy
y2_train_pred=model56.predict(x2_train)
final_training=accuracy_score(y2_train_pred,y2_train)
final_training
# Out:
# 0.5585714285714286

# %%
from sklearn.metrics import confusion_matrix, classification_report

cr = classification_report(y_test, y_pred, target_names=["0", "1"])

print("\nClassification Report:")
print(cr)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.52      0.47      0.49       717
#            1       0.50      0.55      0.52       683
#
#     accuracy                           0.51      1400
#    macro avg       0.51      0.51      0.51      1400
# weighted avg       0.51      0.51      0.51      1400

# %% [markdown]
# # RANDOM FOREST

# %%
model6=RandomForestClassifier()
model6.fit(x2_train, y2_train)
# Out:
# RandomForestClassifier()

# %%
#testing accuracy
y2_pred=model6.predict(x2_test)
fs=accuracy_score(y2_pred,y2_test)
fs
# Out:
# 0.5092857142857142

# %%
#training accuracy
y2_train_pred=model6.predict(x2_train)
final_training=accuracy_score(y2_train_pred,y2_train)
final_training
# Out:
# 1.0

# %%
accuracy =model6.score(x_test, y_test)
print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.5092857142857142

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint


param_dist = {'n_estimators': randint(50,500),
              'max_depth': randint(1,20)}

rf = RandomForestClassifier()

rand_search = RandomizedSearchCV(rf, param_distributions = param_dist,n_iter=5, cv=5,verbose=1, n_jobs=-1)

rand_search.fit(x2_train, y2_train)
print("Best Hyperparameters:")
print(rand_search.best_params_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Best Hyperparameters:
# {'max_depth': 1, 'n_estimators': 407}

# %%
model67=RandomForestClassifier(max_depth=1, n_estimators=407)
model67.fit(x2_train, y2_train)
# Out:
# RandomForestClassifier(max_depth=1, n_estimators=407)

# %%
#testing accuracy
y2_pred=model67.predict(x2_test)
fs=accuracy_score(y2_pred,y2_test)
fs
# Out:
# 0.5092857142857142

# %%
# training accurac
y2_train_pred=model67.predict(x2_train)
final_training=accuracy_score(y2_train_pred,y2_train)
final_training
# Out:
# 0.5264285714285715

# %%
from sklearn.metrics import confusion_matrix, classification_report

cr = classification_report(y_test, y_pred, target_names=["0", "1"])

print("\nClassification Report:")
print(cr)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.52      0.47      0.49       717
#            1       0.50      0.55      0.52       683
#
#     accuracy                           0.51      1400
#    macro avg       0.51      0.51      0.51      1400
# weighted avg       0.51      0.51      0.51      1400

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

xgb = XGBClassifier()

xgb.fit(x2_train, y2_train)
y2_pred = xgb.predict(x2_test)

print("XGBoost Test Accuracy:", accuracy_score(y2_test, y2_pred))
# Out:
# XGBoost Test Accuracy: 0.5071428571428571

# %%
# training accurac
y2_train_pred=xgb.predict(x2_train)
final_training=accuracy_score(y2_train_pred,y2_train)
final_training
# Out:
# 0.9316071428571429
